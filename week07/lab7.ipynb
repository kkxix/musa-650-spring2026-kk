# %%
import geemap
import ee
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'musa-650-spring-2026 (Python 3.11.6)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
